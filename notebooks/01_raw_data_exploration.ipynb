# %% [markdown]
# # Veltis Raw Data Exploration (2023)
#
# This notebook loads and previews the raw data files ingested from external sources.

# %%
# Import Libraries
import pandas as pd
from pathlib import Path
import os

# Configuration
YEAR = 2023
print("Libraries loaded.")
# Out:
# Libraries loaded.

# %%
# Setup Paths
project_root = Path.cwd()
if project_root.name == 'notebooks':
    project_root = project_root.parent

raw_year_dir = project_root / 'data' / 'raw' / str(YEAR)
print(f"Raw {YEAR} Data Path: {raw_year_dir}")
# Out:
# Raw 2023 Data Path: /workspaces/MVP-web-scrapping-project/data/raw/2023

# %%
# List and Preview Files
if not raw_year_dir.exists():
    print("Directory not found! Please run ingestion first.")
else:
    files = list(raw_year_dir.glob('*'))
    print(f"Found {len(files)} files:")
    for f in files:
        print(f"- {f.name}")

    print("\n--- PREVIEWS ---")
    for f in files:
        if f.suffix == '.csv':
            print(f"\nPreviewing {f.name}:")
            try:
                # Specific handling for known tricky files
                if 'finess' in f.name.lower():
                    # FINESS raw data usually has NO header row, just a metadata line at line 0
                    # We skip line 0 (metadata) and read the rest as data with NO header
                    df = pd.read_csv(f, sep=';', encoding='latin-1', header=None, skiprows=1, nrows=5, on_bad_lines='skip')
                    
                    # Optional: Rename a few key columns for clarity if we know the schema
                    # Based on inspection: 1=Finess_ET, 4=RaisonSociale, 22=Siret
                    # But raw exploration often just shows raw structure.
                    print("(Note: File has no headers. showing generic indices)")
                    
                else:
                    # Generic attempt
                    df = pd.read_csv(f, sep=None, engine='python', nrows=5)
                
                display(df.head())
            except Exception as e:
                print(f"Error reading {f.name}: {e}")
        elif f.suffix in ['.xls', '.xlsx']:
            print(f"\nPreviewing {f.name}:")
            try:
                df = pd.read_excel(f, nrows=5)
                display(df.head())
            except Exception as e:
                print(f"Error reading {f.name}: {e}")
# Out:
# Found 4 files:
# - has_etab_geo.csv
# - finess.csv
# - health_metrics.xlsx
# - has_demarche.csv
#
# --- PREVIEWS ---
#
# Previewing has_etab_geo.csv:
#    ﻿"code_demarche"  FINESS_EJ  FINESS_EG  \
# 0             30001  350000402  350002176
# 1             30002  340000272  340024314
# 2             30003  350002291  350000410
# 3             30004  530000249  530000124
# 4             30004  530000249  530010438
#
#                                            RS_eg  Site_Principal
# 0                        CLINIQUE DE L'ESPERANCE            True
# 1              CLINIQUE SAINT JEAN SUD DE FRANCE            True
# 2                    CENTRE HOSPITALIER DE JANZE            True
# 3                   CLINIQUE NOTRE DAME DE PRITZ            True
# 4  CENTRE MEDIPSY - CLINIQUE NOTRE DAME DE PRITZ           False
# Previewing finess.csv:
# (Note: File has no headers. showing generic indices)
#             0         1         2                            3   \
# 0  structureet  10000024  10780054               CH DE FLEYRIAT
# 1  structureet  10000032  10780062                 CH BUGEY SUD
# 2  structureet  10000065  10780096  CH DE TREVOUX - MONTPENSIER
# 3  structureet  10000081  10780112            CH DU PAYS DE GEX
# 4  structureet  10000099  10780120              CH DE MEXIMIEUX
#
#                                                4   5   6    7    8   \
# 0  CENTRE HOSPITALIER DE BOURG-EN-BRESSE FLEYRIAT NaN NaN  900  RTE
# 1                    CENTRE HOSPITALIER BUGEY SUD NaN NaN  700   AV
# 2     CENTRE HOSPITALIER DE TREVOUX - MONTPENSIER NaN NaN   14    R
# 3               CENTRE HOSPITALIER DU PAYS DE GEX NaN NaN  160    R
# 4                 CENTRE HOSPITALIER DE MEXIMIEUX NaN NaN   13   AV
#
#                  9   ...              22     23  24  \
# 0          DE PARIS  ...  26010004500012  8610Z   3
# 1         DE NARVIK  ...  26010003700068  8610Z   3
# 2      DE L'HOPITAL  ...  26010028400017  8610Z   3
# 3     MARC PANISSOD  ...  26010010200011  8610Z   3
# 4  DU DOCTEUR BOYER  ...  26010013600019  8610Z   3
#
#                                                   25 26  \
# 0  ARS Ã©tablissements Publics de santÃ© dotation...  1
# 1  ARS Ã©tablissements Publics de santÃ© dotation...  1
# 2  ARS Ã©tablissements Publics de santÃ© dotation...  1
# 3  ARS Ã©tablissements Publics de santÃ© dotation...  1
# 4  ARS Ã©tablissements Publics de santÃ© dotation...  1
#
#                                27          28          29          30  31
# 0  Etablissement public de santÃ©  1979-02-13  1979-02-13  2020-02-04 NaN
# 1  Etablissement public de santÃ©  1901-01-01  1901-01-01  2021-07-07 NaN
# 2  Etablissement public de santÃ©  1901-01-01  1901-01-01  2018-01-12 NaN
# 3  Etablissement public de santÃ©  1901-01-01  1901-01-01  2020-02-04 NaN
# 4  Etablissement public de santÃ©  1945-01-01  1945-01-01  2020-06-30 NaN
#
# [5 rows x 32 columns]
# Previewing health_metrics.xlsx:
#      finess             rs_finess  finess_geo  \
# 0  10780062   CH DOCTEUR RECAMIER    10000032
# 1  10007987  CH PUBLIC HAUTEVILLE    10000180
# 2  10007987  CH PUBLIC HAUTEVILLE    10000198
# 3  10007987  CH PUBLIC HAUTEVILLE    10000214
# 4  10002129       CR LES ARBELLES    10002129
#
#                             rs_finess_geo                region  \
# 0                            CH BUGEY SUD  Auvergne-Rhône-Alpes
# 1  CH PUBLIC HAUTEVILLE - UNITE ESPERANCE  Auvergne-Rhône-Alpes
# 2  CH PUBLIC HAUTEVILLE - UNITE INTERDEPT  Auvergne-Rhône-Alpes
# 3   CH PUBLIC HAUTEVILLE - UNITE ALBARINE  Auvergne-Rhône-Alpes
# 4                        SSR LES ARBELLES  Auvergne-Rhône-Alpes
#
#                                             type   participation   Depot  \
# 0                            Centre Hospitaliers   2- Facultatif  1- Oui
# 1                            Centre Hospitaliers   2- Facultatif  1- Oui
# 2                            Centre Hospitaliers  1- Obligatoire  1- Oui
# 3                            Centre Hospitaliers  1- Obligatoire  1- Oui
# 4  Etablissements de santé privés à but lucratif  1- Obligatoire  1- Oui
#
#    nb_rep_score_ALL_ssr_ajust  score_ALL_ssr_ajust  ...  \
# 0                         NaN                  NaN  ...
# 1                        80.0                80.76  ...
# 2                       188.0                78.94  ...
# 3                        62.0                80.11  ...
# 4                        85.0                70.85  ...
#
#   nb_rep_score_LIEU_ssr_ajust score_REPAS_ssr_ajust  \
# 0                         NaN                   NaN
# 1                        80.0                 79.18
# 2                       188.0                 69.73
# 3                        62.0                 76.28
# 4                        85.0                 58.03
#
#    nb_rep_score_REPAS_ssr_ajust  score_SORTIE_ssr_ajust  \
# 0                           NaN                     NaN
# 1                          80.0                   75.42
# 2                         188.0                   73.10
# 3                          62.0                   67.45
# 4                          85.0                   63.17
#
#    nb_rep_score_SORTIE_ssr_ajust  score_ALL_ssr_ajust_dp  taux_reco_brut  \
# 0                            NaN                     NaN             NaN
# 1                           80.0                    81.0            80.0
# 2                          188.0                    79.0            80.9
# 3                           62.0                    80.0            82.3
# 4                           85.0                    71.0            33.7
#
#    nb_reco_brut  SCORE_AJUST_ESATIS_REGION  SCORE_AJUST_ESATIS_TYPE
# 0           NaN                        NaN                      NaN
# 1          80.0                      76.02                    77.89
# 2         188.0                      76.02                    77.89
# 3          62.0                      76.02                    77.89
# 4          83.0                      76.02                    73.20
#
# [5 rows x 27 columns]
# Previewing has_demarche.csv:
#    ﻿"code_demarche"  annee_visite   mois_visite date_deb_visite  \
# 0             30001          2021  09-Septembre      21/09/2021
# 1             30002          2023    01-Janvier      24/01/2023
# 2             30003          2022    01-Janvier      19/01/2022
# 3             30004          2021  09-Septembre      28/09/2021
# 4             30005          2021   11-Novembre      29/11/2021
#
#   date_de_decision    Decision_de_la_CCES
# 0       10/02/2022               Certifié
# 1       08/03/2023  Certifié avec mention
# 2       31/03/2022               Certifié
# 3       14/12/2021               Certifié
# 4       31/03/2022               Certifié
