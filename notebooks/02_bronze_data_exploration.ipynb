# %% [markdown]
# # Bronze Data Exploration
#
# This notebook explores the **bronze layer** data after initial cleaning.
#
# **Bronze Layer Characteristics:**
# - Cleaned raw data
# - **Proper column names assigned** (official FINESS structure)
# - Standardized column names (lowercase, no special chars)
# - UTF-8 encoding
# - Duplicates removed
# - All CSV format
# - Ready for transformation

# %%
import pandas as pd
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
pd.set_option('display.width', None)

# Define paths
BRONZE_PATH = Path('../data/bronze/2024')
print(f"Bronze data path: {BRONZE_PATH}")
print(f"Files: {[f.name for f in BRONZE_PATH.glob('*.csv')]}")
# Out:
# Bronze data path: ../data/bronze/2024
# Files: ['health_metrics_clean.csv', 'has_etab_geo_clean.csv', 'has_demarche_clean.csv', 'finess_clean.csv']

# %% [markdown]
# ## 1. FINESS Clean (Establishments)
#
# Now with proper official column names from data.gouv.fr!

# %%
# Load cleaned FINESS
df_finess_bronze = pd.read_csv(BRONZE_PATH / 'finess_clean.csv', low_memory=False)

print(f"Shape: {df_finess_bronze.shape}")
print(f"\nColumn Names (Official FINESS Structure):")
print("="*70)
column_descriptions = {
    'structureet': 'Structure type',
    'finess_et': 'FINESS Establishment ID',
    'finess_ej': 'FINESS Legal Entity ID',
    'rs': 'Short name (Raison Sociale)',
    'rslongue': 'Long name (Raison Sociale Longue)',
    'numvoie': 'Street number',
    'typvoie': 'Street type (rue, avenue, etc.)',
    'voie': 'Street name',
    'lieuditbp': 'Place/BP',
    'ligneacheminement': 'Postal routing (CP + ville)',
    'telephone': 'Phone number',
    'siret': 'SIRET number',
    'libsph': 'SPH label (category detail)',
    'dateouv': 'Opening date',
    'datemaj': 'Last update date'
}

for i, col in enumerate(df_finess_bronze.columns):
    desc = column_descriptions.get(col, '')
    if desc:
        print(f"{i:2d}. {col:20s} - {desc}")
    else:
        print(f"{i:2d}. {col}")
# Out:
# Shape: (204915, 32)
#
# Column Names (Official FINESS Structure):
# ======================================================================
#  0. structureet          - Structure type
#  1. finess_et            - FINESS Establishment ID
#  2. finess_ej            - FINESS Legal Entity ID
#  3. rs                   - Short name (Raison Sociale)
#  4. rslongue             - Long name (Raison Sociale Longue)
#  5. complrs
#  6. compldistrib
#  7. numvoie              - Street number
#  8. typvoie              - Street type (rue, avenue, etc.)
#  9. voie                 - Street name
# 10. compvoie
# 11. lieuditbp            - Place/BP
# 12. commune
# 13. departement
# 14. libdepartement
# 15. ligneacheminement    - Postal routing (CP + ville)
# 16. telephone            - Phone number
# 17. telecopie
# 18. categetab
# 19. libcategetab
# 20. categagretab
# 21. libcategagretab
# 22. siret                - SIRET number
# 23. codeape
# 24. codemft
# 25. libmft
# 26. codesph
# 27. libsph               - SPH label (category detail)
# 28. dateouv              - Opening date
# 29. dateautor
# 30. datemaj              - Last update date
# 31. numuai

# %%
# Show key columns
key_cols = ['finess_et', 'rs', 'rslongue', 'numvoie', 'typvoie', 'voie', 'ligneacheminement', 'siret', 'libsph']
print("Sample of key columns:")
df_finess_bronze[key_cols].head(10)
# Out:
# Sample of key columns:
#    finess_et                                      rs  \
# 0  010000032                            CH BUGEY SUD
# 1  010000065             CH DE TREVOUX - MONTPENSIER
# 2  010000081                       CH DU PAYS DE GEX
# 3  010000099                         CH DE MEXIMIEUX
# 4  010000107                      CH DE PONT DE VAUX
# 5  010000115       CHI AIN VAL DE SAONE - PONT VEYLE
# 6  010000131         CHI AIN VAL DE SAONE - THOISSEY
# 7  010000180  CH PUBLIC HAUTEVILLE - UNITE ESPERANCE
# 8  010000198  CH PUBLIC HAUTEVILLE - UNITE INTERDEPT
# 9  010000214   CH PUBLIC HAUTEVILLE - UNITE ALBARINE
#
#                                             rslongue  numvoie typvoie  \
# 0                       CENTRE HOSPITALIER BUGEY SUD    700.0      AV
# 1        CENTRE HOSPITALIER DE TREVOUX - MONTPENSIER     14.0       R
# 2                  CENTRE HOSPITALIER DU PAYS DE GEX    160.0       R
# 3                    CENTRE HOSPITALIER DE MEXIMIEUX     13.0      AV
# 4                 CENTRE HOSPITALIER DE PONT DE VAUX      NaN     CHE
# 5  CH INTERCOMMUNAL AIN VAL DE SAONE - PONT DE VEYLE      NaN     IMP
# 6       CH INTERCOMMUNAL AIN VAL DE SAONE - THOISSEY     11.0       R
# 7  CENTRE HOSPITALIER PUBLIC DE HAUTEVILLE - UNIT...      NaN      AV
# 8  CENTRE HOSPITALIER PUBLIC DE HAUTEVILLE - UNIT...      NaN      AV
# 9  CENTRE HOSPITALIER PUBLIC DE HAUTEVILLE - UNIT...      NaN      AV
#
#                 voie           ligneacheminement         siret  \
# 0          DE NARVIK                01300 BELLEY  2.601000e+13
# 1       DE L'HOPITAL         01606 TREVOUX CEDEX  2.601003e+13
# 2      MARC PANISSOD             01174 GEX CEDEX  2.601001e+13
# 3   DU DOCTEUR BOYER             01800 MEXIMIEUX  2.601001e+13
# 4         DES NIVRES          01190 PONT DE VAUX  2.601002e+13
# 5  DE LA BISCUITERIE         01290 PONT DE VEYLE           NaN
# 6       DE L HOPITAL              01140 THOISSEY  2.000300e+13
# 7      FELIX MANGINI  01110 PLATEAU D HAUTEVILLE  2.601102e+13
# 8      FELIX MANGINI  01110 PLATEAU D HAUTEVILLE  2.601102e+13
# 9      FELIX MANGINI  01110 PLATEAU D HAUTEVILLE  2.601102e+13
#
#                           libsph
# 0  Etablissement public de santé
# 1  Etablissement public de santé
# 2  Etablissement public de santé
# 3  Etablissement public de santé
# 4  Etablissement public de santé
# 5  Etablissement public de santé
# 6  Etablissement public de santé
# 7  Etablissement public de santé
# 8  Etablissement public de santé
# 9  Etablissement public de santé

# %%
# Data quality check
print("Data Quality:")
print(f"  - Total records: {len(df_finess_bronze):,}")
print(f"  - Duplicates: {df_finess_bronze.duplicated().sum()}")
print(f"  - Memory usage: {df_finess_bronze.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
print(f"\nMissing values in key columns:")
for col in ['finess_et', 'rs', 'rslongue', 'siret', 'ligneacheminement', 'libsph']:
    missing = df_finess_bronze[col].isna().sum()
    pct = (missing / len(df_finess_bronze)) * 100
    print(f"  {col:20s}: {missing:6,} ({pct:5.2f}%)")
# Out:
# Data Quality:
#   - Total records: 204,915
#   - Duplicates: 0
#   - Memory usage: 238.19 MB
#
# Missing values in key columns:
#   finess_et           :      0 ( 0.00%)
#   rs                  :      0 ( 0.00%)
#   rslongue            : 20,674 (10.09%)
#   siret               : 114,386 (55.82%)
#   ligneacheminement   : 102,458 (50.00%)
#   libsph              : 193,062 (94.22%)

# %% [markdown]
# ## 2. HAS Demarche Clean (Certification Process)

# %%
# Load cleaned HAS demarche
df_has_demarche_bronze = pd.read_csv(BRONZE_PATH / 'has_demarche_clean.csv')

print(f"Shape: {df_has_demarche_bronze.shape}")
print(f"\nColumns: {list(df_has_demarche_bronze.columns)}")
print("\nNote: Column names are now standardized (lowercase, no BOM)")
print("\nSample:")
df_has_demarche_bronze.head()
# Out:
# Shape: (2348, 6)
#
# Columns: ['code_demarche', 'annee_visite', 'mois_visite', 'date_deb_visite', 'date_de_decision', 'decision_de_la_cces']
#
# Note: Column names are now standardized (lowercase, no BOM)
#
# Sample:
#    code_demarche  annee_visite   mois_visite date_deb_visite date_de_decision  \
# 0          30001          2021  09-Septembre      21/09/2021       10/02/2022
# 1          30002          2023    01-Janvier      24/01/2023       08/03/2023
# 2          30003          2022    01-Janvier      19/01/2022       31/03/2022
# 3          30004          2021  09-Septembre      28/09/2021       14/12/2021
# 4          30005          2021   11-Novembre      29/11/2021       31/03/2022
#
#      decision_de_la_cces
# 0               Certifié
# 1  Certifié avec mention
# 2               Certifié
# 3               Certifié
# 4               Certifié

# %% [markdown]
# ## 3. HAS Establishment Geography Clean

# %%
# Load cleaned HAS etab geo
df_has_geo_bronze = pd.read_csv(BRONZE_PATH / 'has_etab_geo_clean.csv')

print(f"Shape: {df_has_geo_bronze.shape}")
print(f"\nColumns: {list(df_has_geo_bronze.columns)}")
print("\nSample:")
df_has_geo_bronze.head()
# Out:
# Shape: (8211, 5)
#
# Columns: ['code_demarche', 'finess_ej', 'finess_eg', 'rs_eg', 'site_principal']
#
# Sample:
#    code_demarche  finess_ej  finess_eg  \
# 0          30001  350000402  350002176
# 1          30002  340000272  340024314
# 2          30003  350002291  350000410
# 3          30004  530000249  530000124
# 4          30004  530000249  530010438
#
#                                            rs_eg  site_principal
# 0                        CLINIQUE DE L'ESPERANCE            True
# 1              CLINIQUE SAINT JEAN SUD DE FRANCE            True
# 2                    CENTRE HOSPITALIER DE JANZE            True
# 3                   CLINIQUE NOTRE DAME DE PRITZ            True
# 4  CENTRE MEDIPSY - CLINIQUE NOTRE DAME DE PRITZ           False

# %% [markdown]
# ## 4. Health Metrics Clean (IQSS)

# %%
# Load cleaned health metrics (now CSV instead of Excel)
df_metrics_bronze = pd.read_csv(BRONZE_PATH / 'health_metrics_clean.csv')

print(f"Shape: {df_metrics_bronze.shape}")
print(f"\nColumns ({len(df_metrics_bronze.columns)}):")
for col in df_metrics_bronze.columns:
    print(f"  - {col}")

print("\nNote: Columns are normalized (lowercase, underscores)")
print("\nSample:")
df_metrics_bronze.head()
# Out:
# Shape: (1248, 27)
#
# Columns (27):
#   - finess
#   - rs_finess
#   - finess_geo
#   - rs_finess_geo
#   - region
#   - type
#   - participation
#   - depot
#   - nb_rep_score_all_ssr_ajust
#   - score_all_ssr_ajust
#   - classement
#   - evolution
#   - score_accueil_ssr_ajust
#   - nb_rep_score_accueil_ssr_ajust
#   - score_pec_ssr_ajust
#   - nb_rep_score_pec_ssr_ajust
#   - score_lieu_ssr_ajust
#   - nb_rep_score_lieu_ssr_ajust
#   - score_repas_ssr_ajust
#   - nb_rep_score_repas_ssr_ajust
#   - score_sortie_ssr_ajust
#   - nb_rep_score_sortie_ssr_ajust
#   - score_all_ssr_ajust_dp
#   - taux_reco_brut
#   - nb_reco_brut
#   - score_ajust_esatis_region
#   - score_ajust_esatis_type
#
# Note: Columns are normalized (lowercase, underscores)
#
# Sample:
#       finess             rs_finess finess_geo  \
# 0  010780062   CH DOCTEUR RECAMIER  010000032
# 1  010780112     CH DU PAYS DE GEX  010000081
# 2  010007987  CH PUBLIC HAUTEVILLE  010000180
# 3  010007987  CH PUBLIC HAUTEVILLE  010000198
# 4  010007987  CH PUBLIC HAUTEVILLE  010000214
#
#                             rs_finess_geo                region  \
# 0                            CH BUGEY SUD  Auvergne-Rhône-Alpes
# 1                       CH DU PAYS DE GEX  Auvergne-Rhône-Alpes
# 2  CH PUBLIC HAUTEVILLE - UNITE ESPERANCE  Auvergne-Rhône-Alpes
# 3  CH PUBLIC HAUTEVILLE - UNITE INTERDEPT  Auvergne-Rhône-Alpes
# 4   CH PUBLIC HAUTEVILLE - UNITE ALBARINE  Auvergne-Rhône-Alpes
#
#                   type participation depot  nb_rep_score_all_ssr_ajust  \
# 0  Centre Hospitaliers    Facultatif   Oui                         NaN
# 1  Centre Hospitaliers    Facultatif   Oui                         NaN
# 2  Centre Hospitaliers    Facultatif   Oui                        65.0
# 3  Centre Hospitaliers   Obligatoire   Oui                       203.0
# 4  Centre Hospitaliers   Obligatoire   Oui                        68.0
#
#    score_all_ssr_ajust classement evolution  score_accueil_ssr_ajust  \
# 0                  NaN         DI       NaN                      NaN
# 1                  NaN         DI       NaN                      NaN
# 2                81.46          A    Stable                    91.18
# 3                80.05          A    Stable                    88.52
# 4                82.46          A    Stable                    89.09
#
#    nb_rep_score_accueil_ssr_ajust  score_pec_ssr_ajust  \
# 0                             NaN                  NaN
# 1                             NaN                  NaN
# 2                            65.0                84.76
# 3                           203.0                83.54
# 4                            68.0                84.39
#
#    nb_rep_score_pec_ssr_ajust  score_lieu_ssr_ajust  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                        65.0                 75.24
# 3                       203.0                 79.02
# 4                        68.0                 85.10
#
#    nb_rep_score_lieu_ssr_ajust  score_repas_ssr_ajust  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                         65.0                  79.62
# 3                        203.0                  68.35
# 4                         68.0                  77.22
#
#    nb_rep_score_repas_ssr_ajust  score_sortie_ssr_ajust  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                          65.0                   76.00
# 3                         203.0                   74.56
# 4                          68.0                   73.54
#
#    nb_rep_score_sortie_ssr_ajust  score_all_ssr_ajust_dp  taux_reco_brut  \
# 0                            NaN                     NaN             NaN
# 1                            NaN                     NaN             NaN
# 2                           65.0                    81.0            81.5
# 3                          203.0                    80.0            81.7
# 4                           68.0                    82.0            77.6
#
#    nb_reco_brut  score_ajust_esatis_region  score_ajust_esatis_type
# 0           NaN                        NaN                      NaN
# 1           NaN                        NaN                      NaN
# 2          65.0                      76.82                    78.29
# 3         202.0                      76.82                    78.29
# 4          67.0                      76.82                    78.29

# %%
# Check data types
print("Data types:")
print(df_metrics_bronze.dtypes)
# Out:
# Data types:
# finess                        object
# rs_finess                     object
# finess_geo                    object
# rs_finess_geo                 object
# region                        object
#                               ...
# score_all_ssr_ajust_dp       float64
# taux_reco_brut               float64
# nb_reco_brut                 float64
# score_ajust_esatis_region    float64
# score_ajust_esatis_type      float64
# Length: 27, dtype: object

# %% [markdown]
# ## Comparison: Raw vs Bronze
#
# **Major Improvements in Bronze Layer:**
#
# ### FINESS Data
# - ✓ **Proper column names assigned** (32 official columns from data.gouv.fr)
#   - Before: Unnamed columns like `Unnamed: 5`, `Unnamed: 6`
#   - After: `complrs`, `compldistrib`, etc.
# - ✓ Named-based access instead of positional indexing
#   - Before: `df.iloc[:, 1]`
#   - After: `df['finess_et']`
#
# ### All Data Sources
# - ✓ All files in CSV format (easier to work with)
# - ✓ Column names standardized (lowercase, no special characters)
# - ✓ UTF-8 encoding consistent across all files
# - ✓ Duplicates removed
# - ✓ Categorical values cleaned (numeric prefixes removed)
# - ✓ Numeric columns properly typed
#
# **Next Step:** Run processing pipeline to create silver layer
# ```bash
# python scripts/run_processing.py --year 2024
# ```
